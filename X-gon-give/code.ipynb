# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open ("data/lyrics.txt") as text:
    lyrics = text.read().replace('\n','').lower()

# %%
len(lyrics)
# Out:
# 3443

# %%
lyrics.count("x")
# Out:
# 16

# %%
x_pos = [pos for pos, char in enumerate(lyrics) if char == "x"]

y = [(i/3442) for i in x_pos]

# %%
with plt.xkcd():
    ax = sns.displot(x = x_pos,bins = 17, cumulative = True, kde = True)
    plt.title("How much DMX has given X to you")
    plt.ylabel("Cumulative Count of X")
    plt.xlabel("Progress of Song")
    plt.xticks([( i/100*3442)for i in [25,50,75]],["25%","50%","75%"])
    plt.xlim(0, 3443)
